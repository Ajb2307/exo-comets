# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
pk_df = pd.read_pickle('df_hd.pkl')  
pk_df2 = pd.read_pickle('df2_hd.pkl') 
pk_df3 = pd.read_pickle('df3_hd.pkl')

# %%
# First idea

new_fluxes = []

for key in pk_df.keys():
    new_fluxes.append(np.array(pk_df[key]))

d = {'Object': pk_df.keys(), 'Flux': new_fluxes, 'MJD-Obs':  pk_df2['MJD'], 'Date-Obs':pk_df3['Date-Obs']}
df=pd.DataFrame(data=d)

#df.to_pickle('master_df_hd172555.pkl')

# %%
pk_df_new = pk_df.transpose()

# %%
index = pk_df_new.shape[1]
index
# Out:
# 1170

# %%
pk_df_new.insert(index, 'MJD-Obs', list(pk_df2['MJD']), True)

# %%
pk_df_new.insert(index+1, 'Date-Obs', list(pk_df3['Date-Obs']), True)

# %%
pk_df_new
# Out:
#                                     0         1         2         3         4  \
# ADP.2014-10-01T10:21:59.297  0.820643  0.821662  0.821966  0.818749  0.827753
# ADP.2014-10-01T10:23:12.613  0.808462  0.812972  0.825646  0.816023  0.825784
# ADP.2014-10-01T10:19:23.563  0.813137  0.820030  0.815568  0.814296  0.820129
# ADP.2014-10-01T10:21:02.330  0.827789  0.820455  0.810643  0.816685  0.820258
# ADP.2014-10-01T10:22:20.273  0.817457  0.811806  0.809975  0.809365  0.823448
# ...                               ...       ...       ...       ...       ...
# ADP.2016-04-20T08:25:54.640  0.806725  0.814741  0.806403  0.797748  0.804336
# ADP.2016-04-20T08:25:54.642  0.820437  0.811188  0.810333  0.804006  0.797484
# ADP.2016-04-20T08:25:54.650  0.813481  0.806690  0.801680  0.811570  0.804792
# ADP.2016-04-20T08:25:54.656  0.806505  0.810910  0.807565  0.811025  0.811750
# ADP.2016-04-20T08:25:54.662  0.817463  0.819159  0.809734  0.811984  0.810534
#
# ...

# %%
pk_df_new.to_pickle('master_df_hd172555.pkl')
